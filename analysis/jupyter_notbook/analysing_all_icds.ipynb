# %%
import pandas as pd
import numpy as np
import csv
import matplotlib as mlp
# import matplotlib.pyplot.figure as mp
# import pyplot as pl
import seaborn as sns

# %%
# icds
version_years = pd.read_csv('/home/abel/git_repos/Projektarbeit/analysis/icd10gm_history.csv', sep=';')

# %%
version_years.head()
sns.set_theme(style="whitegrid")
# Out:
#     ver ebene ort art  kapnr grvon   code normcode codeohnepunkt  \
# 0  2007     3   N   X      1   A00  A00.-      A00           A00
# 1  2007     4   T   X      1   A00  A00.0    A00.0          A000
# 2  2007     4   T   X      1   A00  A00.1    A00.1          A001
# 3  2007     4   T   X      1   A00  A00.9    A00.9          A009
# 4  2007     3   N   X      1   A00  A01.-      A01           A01
#
#                                                titel  ... sexfehlertyp altunt  \
# 0                                            Cholera  ...            9   9999
# 1  Cholera durch Vibrio cholerae O:1, Biovar chol...  ...            9   9999
# 2    Cholera durch Vibrio cholerae O:1, Biovar eltor  ...            9   9999
# 3                    Cholera, nicht näher bezeichnet  ...            9   9999
# 4                  Typhus abdominalis und Paratyphus  ...            9   9999
#
#   altob altfehlertyp exot belegt ifsgmeldung ifsglabor vermodif verevent
# ...

# %%
sns.countplot(data=version_years, x="ebene")
# Out:
# <AxesSubplot:xlabel='ebene', ylabel='count'>

# %%
sns.countplot(data=version_years, x="ort", hue="ebene")
# Out:
# <AxesSubplot:xlabel='ort', ylabel='count'>

# %%
sns.countplot(data=version_years, x="art", hue="ebene")
# Out:
# <AxesSubplot:xlabel='art', ylabel='count'>

# %%
sns.countplot(data=version_years, x="kapnr")
# Out:
# <AxesSubplot:xlabel='kapnr', ylabel='count'>

# %%
mlp.pyplot.figure(figsize=(20,5))
g = sns.countplot(data=version_years, x="grvon")
g.tick_params(axis='x', rotation=90)

# %%
#mlp.pyplot.figure(figsize=(20,5))
g = sns.countplot(data=version_years, x="p295")
#g.tick_params(axis='x', rotation=90)

# %%
g = sns.countplot(data=version_years, x="p301")

# %%
g = sns.countplot(data=version_years, x="sexcode")

# %%
ageUno9999 = version_years[version_years['altunt'] != '9999']

# %%
g = sns.countplot(data=ageUno9999, x="altunt")

# %%
ageOno9999 = version_years[version_years['altob'] != '9999']

# %%
g = sns.countplot(data=ageOno9999, x="altob")

# %%
g = sns.countplot(data=version_years, x="belegt")

# %%
g = sns.countplot(data=version_years, x="exot")

# %%
g = sns.countplot(data=version_years, x="ifsgmeldung")

# %%
g = sns.countplot(data=version_years, x="ifsglabor")
