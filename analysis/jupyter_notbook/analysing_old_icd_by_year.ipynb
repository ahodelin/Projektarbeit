# %%
import pandas as pd
import numpy as np
import csv
import matplotlib as mlp
import seaborn as sns

# %%
# icds 2008 - 2021
sns.set_theme(style="whitegrid")
version_years = pd.read_csv('/home/abel/git_repos/Projektarbeit/analysis/icd_deleted_2007_2020.csv', sep=';')
#version_years = version_years[version_years['ver'] != 2007]

# %%
version_years.head()
# Out:
#     ver  ebene ort art  kapnr grvon   code normcode codeohnepunkt  \
# 0  2007      4   T   X      4   E65  E66.1    E66.1          E661
# 1  2007      4   T   X      4   E65  E66.2    E66.2          E662
# 2  2007      4   T   X      4   E65  E66.8    E66.8          E668
# 3  2007      4   T   X      4   E65  E66.9    E66.9          E669
# 4  2007      4   T   X      4   E70  E83.5    E83.5          E835
#
#                                                titel  ... sexfehlertyp altunt  \
# 0                  Arzneimittelinduzierte Adipositas  ...            9   t028
# 1  Übermäßige Adipositas mit alveolärer Hypoventi...  ...            9   t028
# 2                                Sonstige Adipositas  ...            9   t028
# 3                 Adipositas, nicht näher bezeichnet  ...            9   t028
# 4                 Störungen des Kalziumstoffwechsels  ...            9   9999
#
#    altob altfehlertyp exot belegt ifsgmeldung ifsglabor vermodif verevent
# 0   j124            K    N      J           N         N     2008        D
# 1   j124            K    N      J           N         N     2008        D
# 2   j124            K    N      J           N         N     2008        D
# 3   j124            K    N      J           N         N     2008        D
# 4   9999            9    N      J           N         N     2008        D
#
# [5 rows x 31 columns]

# %%
version_years.corr()
# Out:
#                    ver     ebene     kapnr  fuenfsteller  vermodif
# ver           1.000000 -0.088425  0.378138           NaN  0.412556
# ebene        -0.088425  1.000000 -0.035951           NaN -0.045050
# kapnr         0.378138 -0.035951  1.000000           NaN  0.526260
# fuenfsteller       NaN       NaN       NaN           NaN       NaN
# vermodif      0.412556 -0.045050  0.526260           NaN  1.000000

# %%
# deleted icd by year
mlp.pyplot.figure(figsize=(8.5,4))
sns.countplot(data=version_years, x="vermodif")
#mlp.pyplot.title("Neue ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
#mlp.pyplot.legend(title = "Alte Fassungen")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/neuVersionDelete.svg")

# %%
# deleted icd by year
mlp.pyplot.figure(figsize=(8.5,4))
sns.countplot(data=version_years, x="ver")
#mlp.pyplot.title("Neue ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Alte Fassungen")
#mlp.pyplot.legend(title = "Alte Fassungen")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/oldVersionDelete.svg")

# %%
#fig, catplot = mlp.pyplot.figure(figsize=(8.5,4))
sexno9 = version_years[version_years['sexcode'] != '9']
g = sns.catplot(data=version_years, x="vermodif", hue="ver", col="ort", kind="count",  height=4, aspect=1.5, legend=False)
#g.set_titles("Ort {col_name}")

(g.set_axis_labels("Neue Fassungen", "Gelöschte ICD-10-GM")
 .set_titles("Geschlecht {col_name}")
 #.legend(title="Versionen")
)
#sns.cat.legend(fontsize = 10)
#mlp.pyplot.title("Neue ICD-10-GM pro Jahr")
mlp.pyplot.legend(title = "Alte Fassungen")
#.set_titles("test..")
#mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
#mlp.pyplot.xlabel("Alte Fassungen/Versionen")

# %%
#fig, catplot = mlp.pyplot.figure(figsize=(8.5,4))

g = sns.catplot(data=version_years, x="vermodif", hue="ver", col="art", kind="count",  height=4, aspect=1.5, legend=False)
#g.set_titles("Ort {col_name}")

(g.set_axis_labels("Neue Fassungen", "Anzahl gelöschter ICD-10-GM")
 .set_titles("Art {col_name}")
 #.legend(title="Versionen")
)
#sns.cat.legend(fontsize = 10)
#mlp.pyplot.title("Neue ICD-10-GM pro Jahr")
mlp.pyplot.legend(title = "Alte Fassungen")
#.set_titles("test..")
#mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
#mlp.pyplot.xlabel("Alte Fassungen/Versionen")

# %%
# deleted icd by year
mlp.pyplot.figure(figsize=(8.5,3))
sns.countplot(data=version_years, x="vermodif", hue="ort")
#mlp.pyplot.title("Neue ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.legend(labels=["Nicht terminale Codes", "Terminale Codes"])
mlp.pyplot.xlabel("Fassungen")
#mlp.pyplot.legend(title = "Ort")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/oldicdyear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))
sns.countplot(data=version_years, x="vermodif", hue="ebene")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Neue Fassungen")
mlp.pyplot.legend(labels=["Dreisteller", "Viersteller", "Fünfsteller"], title = "Ebene der gelöschten ICD-10-GM")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/ebeneoldYear.svg")

# %%
#mlp.pyplot.figure(figsize=(10,5))
#sns.countplot(data=version_years, x="ver", hue="art")

# %%
mlp.pyplot.figure(figsize=(10,5))
sns.countplot(data=version_years, x="vermodif", hue="ort")
#mlp.pyplot.title("Terminale und nicht terminale Codes pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Neue Fassungen")
mlp.pyplot.legend(labels=["Nicht terminale Codes", "Terminale Codes"])
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/ortoldYear.svg")

# %%
o = version_years
o.head()
# Out:
#     ver  ebene       ort art  kapnr grvon   code normcode codeohnepunkt  \
# 0  2007      4  Terminal   X      4   E65  E66.1    E66.1          E661
# 1  2007      4  Terminal   X      4   E65  E66.2    E66.2          E662
# 2  2007      4  Terminal   X      4   E65  E66.8    E66.8          E668
# 3  2007      4  Terminal   X      4   E65  E66.9    E66.9          E669
# 4  2007      4  Terminal   X      4   E70  E83.5    E83.5          E835
#
#                                                titel  ... sexfehlertyp altunt  \
# 0                  Arzneimittelinduzierte Adipositas  ...            9   t028
# 1  Übermäßige Adipositas mit alveolärer Hypoventi...  ...            9   t028
# 2                                Sonstige Adipositas  ...            9   t028
# 3                 Adipositas, nicht näher bezeichnet  ...            9   t028
# 4                 Störungen des Kalziumstoffwechsels  ...            9   9999
#
#    altob altfehlertyp exot belegt ifsgmeldung ifsglabor vermodif verevent
# 0   j124            K    N      J           N         N     2008        D
# 1   j124            K    N      J           N         N     2008        D
# 2   j124            K    N      J           N         N     2008        D
# 3   j124            K    N      J           N         N     2008        D
# 4   9999            9    N      J           N         N     2008        D
#
# [5 rows x 31 columns]

# %%
o = version_years
o['ort'] = o['ort'].replace(['T'], 'Terminal')
o['ort'] = o['ort'].replace(['N'], 'Nicht terminal')
mlp.pyplot.figure(figsize=(5,5))
sns.countplot(data=o, x="ort")
#mlp.pyplot.title("Terminale und nicht terminale Codes pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Hierarchie der Schlüsselnummer")
#mlp.pyplot.legend(labels=["Nicht terminale Codes", "Terminale Codes"])
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/ortoldYear.svg")

# %%
kapmore20 = pd.read_csv('/home/abel/git_repos/Projektarbeit/analysis/kapmore20_2008_2021.csv', sep=';')
mlp.pyplot.figure(figsize=(18,9))

sns.countplot(data=kapmore20, x="ver", hue="kapnr")
mlp.pyplot.legend(labels =["Neubildungen",
"Endokrine, Ernährungs- und Stoffwechselkrankheiten",
"Krankheiten des Kreislaufsystems",
"Krankheiten des Verdauungssystems",
"Krankheiten des Muskel-Skelett-Systems und des Bindegewebes",
"Krankheiten des Urogenitalsystems",
"Verletzungen, Vergiftungen und bestimmte andere Folgen äußerer Ursachen",
"Schlüsselnummern für besondere Zwecke"
], title = "Kapitel",  loc='upper left')
mlp.pyplot.title("Meist repräsentierte Kapitel der neuen ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl")
mlp.pyplot.xlabel("Fassungen/Versionen")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/kaptnrYear.svg")
#mlp.pyplot.figure(figsize=(40,20))

# %%
mlp.pyplot.figure(figsize=(6,5))
sexno9 = version_years[version_years['sexcode'] != '9']

sns.countplot(data=sexno9, x="vermodif", hue="sexcode")
#mlp.pyplot.title("Geschlechtsbezug der neuen ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["männlich", "weiblich"])
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/sexoldYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))

sns.countplot(data=version_years, x="vermodif", hue="exot")
# mlp.pyplot.title("Seltene Krankheiten in Mitteleuropa pro Jahr")
mlp.pyplot.ylabel("Anzahl")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["Nein", "Ja"], title = "Exotische Krankheiten")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/exoOLDYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))

sns.countplot(data=version_years, x="vermodif", hue="ifsgmeldung")
# mlp.pyplot.title("Arzt-Meldepflicht pro Jahr")
mlp.pyplot.ylabel("Anzahl gelöschte ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["Nein", "Ja"], title = "Arzt-Meldepflicht")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/arztOLDYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))

sns.countplot(data=version_years, x="ver", hue="ifsglabor")
# mlp.pyplot.title("Auswahl der Laborausschlussziffer")
mlp.pyplot.ylabel("Anzahl gelöschter ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["N nein", "J Ja"], title = "Laborausschlussziffer")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/laborOLDYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))
alter = version_years = version_years[version_years['alter'] != "99999999"]
sns.countplot(data=alter, x="ver", hue="alter")
mlp.pyplot.title("Altersbezug")
mlp.pyplot.ylabel("Anzahl")
mlp.pyplot.xlabel("Fassungen/Versionen")
mlp.pyplot.legend(labels = ["18 bis 124 Jahre",
"1 bis 124 Jahre",
"28 bis 124 Jahre",
"1 Tag bis 1 Jahr",
"1 Tag bis 14 Jahre",
"15 bis 124 Jahre",
"12 bis 55 Jahre",
"3 bis 18 Jahre",
"0 bis 124 Jahre"], 
                  title = "Altersbezug", loc = 'upper center')
#mlp.pyplot.legend(bbox_to_anchor=(1.02, 0.15), loc='right', borderaxespad=0)
# mlp.pyplot.legend(labels = ["N nein", "J Ja"], title = "Altersbezug")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/alterYear.svg")
