# %%
import pandas as pd
import numpy as np
import csv
import matplotlib as mlp
import seaborn as sns

# %%
# icds 2008 - 2021
version_years = pd.read_csv('/home/abel/git_repos/Projektarbeit/analysis/icd_by_year_alter.csv', sep=';')
version_years = version_years[version_years['ver'] != 2007]

# %%
version_years.head()
sns.set_theme(style="whitegrid")

# %%
mlp.pyplot.figure(figsize=(7.5,4))
sns.countplot(data=version_years, x="ver")
#mlp.pyplot.title("Neue ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/newicdyear.svg")

# %%
mlp.pyplot.figure(figsize=(10,6))

sns.countplot(data=version_years, x="ver", hue="ebene")
#mlp.pyplot.title("Ebene der neuen ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl neue ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels=["Dreisteller", "Viersteller", "Fünfsteller"], title = "Ebene")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/ebeneYear.svg")

# %%
#mlp.pyplot.figure(figsize=(10,5))
#sns.countplot(data=version_years, x="ver", hue="art")

# %%
mlp.pyplot.figure(figsize=(10,5))
sns.countplot(data=version_years, x="ver", hue="ort")
# mlp.pyplot.title("Terminale und nicht terminale Codes pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels=["Nicht terminale Codes", "Terminale Codes"])
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/ortYear.svg")

# %%
mlp.pyplot.figure(figsize=(40,20))
sns.countplot(data=version_years, x="ver", hue="kapnr")
#sns.set(font_scale = 2)
mlp.pyplot.title("Kapitel der neuen ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl")
mlp.pyplot.xlabel("Fassungen/Versionen")
mlp.pyplot.legend(labels =["01 Bestimmte infektiöse und parasitäre Krankheiten",
"02 Neubildungen",
"03 Krankheiten des Blutes und der blutbildenden Organe\nsowie bestimmte Störungen mit Beteiligung des Immunsystems",
"04 Endokrine, Ernährungs- und Stoffwechselkrankheiten",
"05 Psychische und Verhaltensstörungen",
"06 Krankheiten des Nervensystems",
"07 Krankheiten des Auges und der Augenanhangsgebilde",
"08 Krankheiten des Ohres und des Warzenfortsatzes",
"09 Krankheiten des Kreislaufsystems",
"10 Krankheiten des Atmungssystems",
"11 Krankheiten des Verdauungssystems",
"12 Krankheiten der Haut und der Unterhaut",
"13 Krankheiten des Muskel-Skelett-Systems\nund des Bindegewebes",
"14 Krankheiten des Urogenitalsystems",
"15 Schwangerschaft, Geburt und Wochenbett",
"16 Bestimmte Zustände, die ihren Ursprung\nin der Perinatalperiode haben",
"17 Angeborene Fehlbildungen, Deformitäten\nund Chromosomenanomalien",
"18 Symptome und abnorme klinische und Laborbefunde,\ndie anderenorts nicht klassifiziert sind",
"19 Verletzungen, Vergiftungen und bestimmte andere\nFolgen äußerer Ursachen",
"20 Äußere Ursachen von Morbidität und Mortalität",
"21 Faktoren, die den Gesundheitszustand beeinflussen\nund zur Inanspruchnahme des Gesundheitswesens führen",
"22 Schlüsselnummern für besondere Zwecke"
], title = "Kapitel", fontsize = 'large', title_fontsize = "10")
# mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/kaptnrYear.svg")

# %%
kapmore20 = pd.read_csv('/home/abel/git_repos/Projektarbeit/analysis/kapmore20_2008_2021.csv', sep=';')
mlp.pyplot.figure(figsize=(18,9))

sns.countplot(data=kapmore20, x="ver", hue="kapnr")
mlp.pyplot.legend(labels =["Neubildungen",
"Endokrine, Ernährungs- und Stoffwechselkrankheiten",
"Krankheiten des Kreislaufsystems",
"Krankheiten des Verdauungssystems",
"Krankheiten des Muskel-Skelett-Systems und des Bindegewebes",
"Krankheiten des Urogenitalsystems",
"Verletzungen, Vergiftungen und bestimmte andere Folgen äußerer Ursachen",
"Schlüsselnummern für besondere Zwecke"
], title = "Kapitel",  loc='upper left')
# mlp.pyplot.title("Meist repräsentierte Kapitel der neuen ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/kaptnrYear.svg")
#mlp.pyplot.figure(figsize=(40,20))

# %%
mlp.pyplot.figure(figsize=(6,5))
sexno9 = version_years[version_years['sexcode'] != '9']

sns.countplot(data=sexno9, x="ver", hue="sexcode")
# mlp.pyplot.title("Geschlechtsbezug der neuen ICD-10-GM pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["männlich", "weiblich"])
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/sexYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))

sns.countplot(data=version_years, x="ver", hue="exot")
# mlp.pyplot.title("Seltene Krankheiten in Mitteleuropa pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["Nein", "Ja"], title = "Exotische Krankheiten")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/exoYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))

sns.countplot(data=version_years, x="ver", hue="ifsgmeldung")
#mlp.pyplot.title("Arzt-Meldepflicht pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["Nein", "Ja"], title = "Arzt-Meldepflicht")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/arztYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))
meldung = version_years[version_years['ifsgmeldung'] != 'N']


sns.countplot(data=meldung, x="ver")
#mlp.pyplot.title("Arzt-Meldepflicht pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
#mlp.pyplot.legend(labels = ["Nein", "Ja"], title = "Arzt-Meldepflicht")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/arztJaYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))
meldung = version_years[version_years['exot'] != 'N']


sns.countplot(data=meldung, x="ver")
#mlp.pyplot.title("Arzt-Meldepflicht pro Jahr")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
#mlp.pyplot.legend(labels = ["Nein", "Ja"], title = "Arzt-Meldepflicht")
#mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/exotJaYear.svg")
# Out:
# Text(0.5, 0, 'Fassungen')

# %%
mlp.pyplot.figure(figsize=(10,5))

sns.countplot(data=version_years, x="ver", hue="ifsglabor")
# mlp.pyplot.title("Auswahl der Laborausschlussziffer")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["N nein", "J Ja"], title = "Laborausschlussziffer", loc = "upper center")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/laborYear.svg")

# %%
mlp.pyplot.figure(figsize=(10,5))
alter = version_years = version_years[version_years['alter'] != "99999999"]
sns.catplot(data=alter, x="ver", hue="alter", legend = False, kind="count", height=7, aspect=1.5)
#mlp.pyplot.title("Altersbezug")
mlp.pyplot.ylabel("Anzahl neuer ICD-10-GM")
mlp.pyplot.xlabel("Fassungen")
mlp.pyplot.legend(labels = ["18 bis 124 Jahre",
"1 bis 124 Jahre",
"28 bis 124 Jahre",
"1 Tag bis 1 Jahr",
"1 Tag bis 14 Jahre",
"15 bis 124 Jahre",
"12 bis 55 Jahre",
"3 bis 18 Jahre",
"0 bis 124 Jahre"], 
                  title = "Altersbezug", loc = 'upper center')
#mlp.pyplot.legend(bbox_to_anchor=(1.02, 0.15), loc='right', borderaxespad=0)
# mlp.pyplot.legend(labels = ["N nein", "J Ja"], title = "Altersbezug")
mlp.pyplot.savefig("/home/abel/git_repos/Projektarbeit/figures/alterYear.svg")
